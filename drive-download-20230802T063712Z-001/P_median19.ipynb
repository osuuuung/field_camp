# %%
# !pip install pulp

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %%
data_path='data.csv'
data=pd.read_csv(data_path,encoding='cp949')
data.head()
# Out:
#   수요지 id           X          Y  초등학령인구
# 0     C1  126.371505  37.463782       1
# 1     C2  126.479505  37.495782      46
# 2     C3  126.481505  37.499782      36
# 3     C4  126.482505  37.495782      81
# 4     C5  126.483505  37.497782      25

# %%
target_path='target.csv'
target=pd.read_csv(target_path,encoding='cp949')
target.head()
# Out:
#   학교 id           X          Y
# 0    F1  126.543921  37.467292
# 1    F2  126.568726  37.496302
# 2    F3  126.492770  37.484428
# 3    F4  126.629683  37.495781
# 4    F5  126.528286  37.450285

# %%
def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # 지구 반지름 (킬로미터)

    # 위도와 경도를 라디안으로 변환
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])

    # 위도와 경도의 차이 계산
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    # 허버사인 공식
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    distance = R * c

    return distance

# %%
s=data['초등학령인구'].sum()
s/750
# Out:
# 13.614666666666666

# %%
s/200
# Out:
# 51.055

# %%
import pulp
from pulp import LpConstraint

# 데이터 초기화 부분
# ----------------------------------------------
# i의 개수, 즉 수요지의 개수
num_i = data.shape[0]

# j의 개수, 즉 시설물 입지점의 개수
num_j = target.shape[0]

# a_i 값의 리스트. 각 수요지 i의 수요량을 나타냅니다.
a = []
for i in data['초등학령인구']:
  a.append(i)

# b_ij 값의 2차원 리스트. 수요지 i와 시설물 입지점 j 사이의 거리를 나타냅니다.
# 예: b = [[b_11, b_12, ...], [b_21, b_22, ...], ...]
b = []

# 각 수요지에서 모든 시설물까지의 거리를 계산
for i, data_row in data.iterrows():
    distances_for_this_demand = []
    for j, target_row in target.iterrows():
        distance = haversine_distance(data_row['Y'], data_row['X'], target_row['Y'], target_row['X'])
        distances_for_this_demand.append(distance)
    b.append(distances_for_this_demand)

# 설치할 시설물의 개수
# 14개 이상 50개 이하
p = 19
# ----------------------------------------------

# LP 문제 정의. 여기서는 총 거리를 최소화하는 것이 목적입니다.
prob = pulp.LpProblem("Binary_Optimization", pulp.LpMinimize)

# 변수 정의 부분
# ----------------------------------------------
# l_ij는 노드 j의 시설물이 노드 i의 총 수요를 충족하면 1, 아니면 0입니다.
l = pulp.LpVariable.dicts("l", (range(num_i), range(num_j)), 0, 1, pulp.LpBinary)

# k_j는 노드 j에 시설물이 설치되면 1, 아니면 0입니다.
k = pulp.LpVariable.dicts("k", range(num_j), 0, 1, pulp.LpBinary)
# ----------------------------------------------
g = [1]*50
for j in [0, 1, 2, 4, 28, 32, 33, 34, 35, 36, 37, 39, 40, 41, 43, 44, 45, 46, 47, 48, 49]:
    g[j] = 3 
# 목적함수 정의. 각 수요지와 시설물 입지점 사이의 거리와 해당 수요지의 수요량을 곱한 값을 최소화합니다.
prob += pulp.lpSum([a[i] * b[i][j] * l[i][j] * g[j] for i in range(num_i) for j in range(num_j)])

# 제약조건 설정 부분
# ----------------------------------------------
# 각 수요지 i는 정확히 하나의 시설물 j에만 할당되어야 합니다.
for i in range(num_i):
    prob += pulp.lpSum([l[i][j] for j in range(num_j)]) == 1

# 설치된 시설물의 총 개수는 p와 동일해야 합니다.
prob += pulp.lpSum([k[j] for j in range(num_j)]) == p

# l_ij는 k_j에 의존적입니다. 즉, k_j가 1일 때만 l_ij는 1이 될 수 있습니다.
for i in range(num_i):
    for j in range(num_j):
        prob += l[i][j] <= k[j]

# 각 시설물 j에 할당된 총 수요량을 계산하고, 그 값이 200과 750 사이에 있도록 제약 조건을 설정합니다.
for j in range(num_j):
    total_demand_for_j = pulp.lpSum([a[i] * l[i][j] for i in range(num_i)])
    prob += total_demand_for_j >= 200 * k[j]  # 시설물이 설치되었을 때만 제약이 활성화되어야 합니다.
    prob += total_demand_for_j <= 750 * k[j]  # 시설물이 설치되었을 때만 제약이 활성화되어야 합니다.

# 각 거리 b_ij는 최대 1.5km까지만 허용됩니다.
for i in range(num_i):
    # 가능한 시설물 할당 리스트 구하기
    possible_assignments = [j for j in range(num_j) if b[i][j] <= 2]
    if b[i][j] > 2 :
        prob += l[i][j] == 0 
    

# 시설물 입지점 1, 4, 5, 7, 11, 15 가 할당되지 않도록 하는 제약식 추가
excluded_facility_indices = [0, 3, 4, 6, 10, 18]  # 시설물 입지점 인덱스는 0부터 시작

for j in excluded_facility_indices:
    prob += k[j] == 0
# ----------------------------------------------

# 최적화 문제 풀기
prob.solve()

# 결과 출력 부분
# ----------------------------------------------
print(f"Status: {pulp.LpStatus[prob.status]}")

# 각 수요지에 할당된 시설물 입지점 출력 (값이 1인 경우만 출력)
for i in range(num_i):
    for j in range(num_j):
        if l[i][j].varValue == 1:
            print(f"수요지 {i+1}는 시설물 입지점 {j+1}에 할당됨")

# 설치된 시설물 입지점만 출력 (값이 1인 경우만 출력)
for j in range(num_j):
    if k[j].varValue == 1:
        print(f"시설물 입지점 {j+1}에 설치됨")

# 할당된 시설물 입지점 및 연결된 수요지 정보를 저장할 리스트
assigned_data = []

# 설치된 시설물 입지점 및 배정된 수요량 정보를 저장할 리스트
facility_demand_data = []

# 각 수요지에 할당된 시설물 입지점 정보 추출
for j in range(num_j):
    if k[j].varValue == 1:
        connected_demands = [i+1 for i in range(num_i) if l[i][j].varValue == 1]
        assigned_data.append({'시설물_입지점': j+1, '연결된_수요지': connected_demands})

        total_demand_for_j = sum([a[i-1] for i in connected_demands]) # <- 수정된 부분
        facility_demand_data.append({'시설물_입지점': j+1, '배정된_수요량': total_demand_for_j})

# 데이터프레임으로 변환 후 출력
assigned_df = pd.DataFrame(assigned_data)
print(assigned_df)

facility_demand_df = pd.DataFrame(facility_demand_data)
print(facility_demand_df)
# Out:
# Status: Optimal
# 수요지 1는 시설물 입지점 39에 할당됨
# 수요지 2는 시설물 입지점 45에 할당됨
# 수요지 3는 시설물 입지점 47에 할당됨
# 수요지 4는 시설물 입지점 45에 할당됨
# 수요지 5는 시설물 입지점 45에 할당됨
# 수요지 6는 시설물 입지점 47에 할당됨
# 수요지 7는 시설물 입지점 47에 할당됨
# 수요지 8는 시설물 입지점 47에 할당됨
# 수요지 9는 시설물 입지점 47에 할당됨
# 수요지 10는 시설물 입지점 45에 할당됨
# 수요지 11는 시설물 입지점 47에 할당됨
# 수요지 12는 시설물 입지점 47에 할당됨
# 수요지 13는 시설물 입지점 3에 할당됨
# 수요지 14는 시설물 입지점 45에 할당됨
# 수요지 15는 시설물 입지점 45에 할당됨
# 수요지 16는 시설물 입지점 45에 할당됨
# 수요지 17는 시설물 입지점 47에 할당됨
# 수요지 18는 시설물 입지점 47에 할당됨
# 수요지 19는 시설물 입지점 47에 할당됨
# 수요지 20는 시설물 입지점 47에 할당됨
# 수요지 21는 시설물 입지점 47에 할당됨
# 수요지 22는 시설물 입지점 47에 할당됨
# 수요지 23는 시설물 입지점 3에 할당됨
# 수요지 24는 시설물 입지점 45에 할당됨
# 수요지 25는 시설물 입지점 44에 할당됨
# 수요지 26는 시설물 입지점 3에 할당됨
# 수요지 27는 시설물 입지점 44에 할당됨
# 수요지 28는 시설물 입지점 3에 할당됨
# 수요지 29는 시설물 입지점 44에 할당됨
# 수요지 30는 시설물 입지점 44에 할당됨
# 수요지 31는 시설물 입지점 47에 할당됨
# 수요지 32는 시설물 입지점 47에 할당됨
# 수요지 33는 시설물 입지점 40에 할당됨
# 수요지 34는 시설물 입지점 47에 할당됨
# 수요지 35는 시설물 입지점 40에 할당됨
# 수요지 36는 시설물 입지점 44에 할당됨
# 수요지 37는 시설물 입지점 47에 할당됨
# 수요지 38는 시설물 입지점 39에 할당됨
# 수요지 39는 시설물 입지점 40에 할당됨
# 수요지 40는 시설물 입지점 39에 할당됨
# 수요지 41는 시설물 입지점 39에 할당됨
# 수요지 42는 시설물 입지점 39에 할당됨
# 수요지 43는 시설물 입지점 39에 할당됨
# 수요지 44는 시설물 입지점 39에 할당됨
# 수요지 45는 시설물 입지점 39에 할당됨
# 수요지 46는 시설물 입지점 37에 할당됨
# 수요지 47는 시설물 입지점 37에 할당됨
# 수요지 48는 시설물 입지점 48에 할당됨
# 수요지 49는 시설물 입지점 37에 할당됨
# 수요지 50는 시설물 입지점 37에 할당됨
# 수요지 51는 시설물 입지점 37에 할당됨
# 수요지 52는 시설물 입지점 37에 할당됨
# 수요지 53는 시설물 입지점 37에 할당됨
# 수요지 54는 시설물 입지점 37에 할당됨
# 수요지 55는 시설물 입지점 37에 할당됨
# 수요지 56는 시설물 입지점 37에 할당됨
# 수요지 57는 시설물 입지점 37에 할당됨
# 수요지 58는 시설물 입지점 37에 할당됨
# 수요지 59는 시설물 입지점 37에 할당됨
# 수요지 60는 시설물 입지점 37에 할당됨
# 수요지 61는 시설물 입지점 39에 할당됨
# 수요지 62는 시설물 입지점 37에 할당됨
# 수요지 63는 시설물 입지점 37에 할당됨
# 수요지 64는 시설물 입지점 37에 할당됨
# 수요지 65는 시설물 입지점 37에 할당됨
# 수요지 66는 시설물 입지점 37에 할당됨
# 수요지 67는 시설물 입지점 37에 할당됨
# 수요지 68는 시설물 입지점 48에 할당됨
# 수요지 69는 시설물 입지점 48에 할당됨
# 수요지 70는 시설물 입지점 37에 할당됨
# 수요지 71는 시설물 입지점 37에 할당됨
# 수요지 72는 시설물 입지점 37에 할당됨
# 수요지 73는 시설물 입지점 37에 할당됨
# 수요지 74는 시설물 입지점 37에 할당됨
# 수요지 75는 시설물 입지점 48에 할당됨
# 수요지 76는 시설물 입지점 37에 할당됨
# 수요지 77는 시설물 입지점 39에 할당됨
# 수요지 78는 시설물 입지점 35에 할당됨
# 수요지 79는 시설물 입지점 35에 할당됨
# 수요지 80는 시설물 입지점 34에 할당됨
# 수요지 81는 시설물 입지점 34에 할당됨
# 수요지 82는 시설물 입지점 35에 할당됨
# 수요지 83는 시설물 입지점 39에 할당됨
# 수요지 84는 시설물 입지점 35에 할당됨
# 수요지 85는 시설물 입지점 39에 할당됨
# 수요지 86는 시설물 입지점 39에 할당됨
# 수요지 87는 시설물 입지점 2에 할당됨
# 수요지 88는 시설물 입지점 34에 할당됨
# 수요지 89는 시설물 입지점 39에 할당됨
# 수요지 90는 시설물 입지점 2에 할당됨
# 수요지 91는 시설물 입지점 2에 할당됨
# 수요지 92는 시설물 입지점 34에 할당됨
# 수요지 93는 시설물 입지점 2에 할당됨
# 수요지 94는 시설물 입지점 23에 할당됨
# 수요지 95는 시설물 입지점 23에 할당됨
# 수요지 96는 시설물 입지점 22에 할당됨
# 수요지 97는 시설물 입지점 23에 할당됨
# 수요지 98는 시설물 입지점 22에 할당됨
# 수요지 99는 시설물 입지점 22에 할당됨
# 수요지 100는 시설물 입지점 23에 할당됨
# 수요지 101는 시설물 입지점 23에 할당됨
# 수요지 102는 시설물 입지점 23에 할당됨
# 수요지 103는 시설물 입지점 22에 할당됨
# 수요지 104는 시설물 입지점 22에 할당됨
# 수요지 105는 시설물 입지점 22에 할당됨
# 수요지 106는 시설물 입지점 22에 할당됨
# 수요지 107는 시설물 입지점 22에 할당됨
# 수요지 108는 시설물 입지점 22에 할당됨
# 수요지 109는 시설물 입지점 22에 할당됨
# 수요지 110는 시설물 입지점 22에 할당됨
# 수요지 111는 시설물 입지점 22에 할당됨
# 수요지 112는 시설물 입지점 22에 할당됨
# 수요지 113는 시설물 입지점 22에 할당됨
# 수요지 114는 시설물 입지점 22에 할당됨
# 수요지 115는 시설물 입지점 22에 할당됨
# 수요지 116는 시설물 입지점 6에 할당됨
# 수요지 117는 시설물 입지점 22에 할당됨
# 수요지 118는 시설물 입지점 22에 할당됨
# 수요지 119는 시설물 입지점 22에 할당됨
# 수요지 120는 시설물 입지점 22에 할당됨
# 수요지 121는 시설물 입지점 22에 할당됨
# 수요지 122는 시설물 입지점 22에 할당됨
# 수요지 123는 시설물 입지점 22에 할당됨
# 수요지 124는 시설물 입지점 22에 할당됨
# 수요지 125는 시설물 입지점 22에 할당됨
# 수요지 126는 시설물 입지점 22에 할당됨
# 수요지 127는 시설물 입지점 22에 할당됨
# 수요지 128는 시설물 입지점 22에 할당됨
# 수요지 129는 시설물 입지점 18에 할당됨
# 수요지 130는 시설물 입지점 22에 할당됨
# 수요지 131는 시설물 입지점 22에 할당됨
# 수요지 132는 시설물 입지점 22에 할당됨
# 수요지 133는 시설물 입지점 22에 할당됨
# 수요지 134는 시설물 입지점 22에 할당됨
# 수요지 135는 시설물 입지점 22에 할당됨
# 수요지 136는 시설물 입지점 22에 할당됨
# 수요지 137는 시설물 입지점 22에 할당됨
# 수요지 138는 시설물 입지점 6에 할당됨
# 수요지 139는 시설물 입지점 18에 할당됨
# 수요지 140는 시설물 입지점 22에 할당됨
# 수요지 141는 시설물 입지점 22에 할당됨
# 수요지 142는 시설물 입지점 22에 할당됨
# 수요지 143는 시설물 입지점 22에 할당됨
# 수요지 144는 시설물 입지점 18에 할당됨
# 수요지 145는 시설물 입지점 18에 할당됨
# 수요지 146는 시설물 입지점 18에 할당됨
# 수요지 147는 시설물 입지점 18에 할당됨
# 수요지 148는 시설물 입지점 22에 할당됨
# 수요지 149는 시설물 입지점 22에 할당됨
# 수요지 150는 시설물 입지점 22에 할당됨
# 수요지 151는 시설물 입지점 22에 할당됨
# 수요지 152는 시설물 입지점 22에 할당됨
# 수요지 153는 시설물 입지점 18에 할당됨
# 수요지 154는 시설물 입지점 18에 할당됨
# 수요지 155는 시설물 입지점 18에 할당됨
# 수요지 156는 시설물 입지점 18에 할당됨
# 수요지 157는 시설물 입지점 22에 할당됨
# 수요지 158는 시설물 입지점 22에 할당됨
# 수요지 159는 시설물 입지점 22에 할당됨
# 수요지 160는 시설물 입지점 22에 할당됨
# 수요지 161는 시설물 입지점 20에 할당됨
# 수요지 162는 시설물 입지점 18에 할당됨
# 수요지 163는 시설물 입지점 18에 할당됨
# 수요지 164는 시설물 입지점 18에 할당됨
# 수요지 165는 시설물 입지점 18에 할당됨
# 수요지 166는 시설물 입지점 18에 할당됨
# 수요지 167는 시설물 입지점 18에 할당됨
# 수요지 168는 시설물 입지점 18에 할당됨
# 수요지 169는 시설물 입지점 18에 할당됨
# 수요지 170는 시설물 입지점 22에 할당됨
# 수요지 171는 시설물 입지점 20에 할당됨
# 수요지 172는 시설물 입지점 20에 할당됨
# 수요지 173는 시설물 입지점 18에 할당됨
# 수요지 174는 시설물 입지점 18에 할당됨
# 수요지 175는 시설물 입지점 18에 할당됨
# 수요지 176는 시설물 입지점 18에 할당됨
# 수요지 177는 시설물 입지점 22에 할당됨
# 수요지 178는 시설물 입지점 20에 할당됨
# 수요지 179는 시설물 입지점 20에 할당됨
# 수요지 180는 시설물 입지점 20에 할당됨
# 수요지 181는 시설물 입지점 20에 할당됨
# 수요지 182는 시설물 입지점 18에 할당됨
# 수요지 183는 시설물 입지점 18에 할당됨
# 수요지 184는 시설물 입지점 18에 할당됨
# 수요지 185는 시설물 입지점 18에 할당됨
# 수요지 186는 시설물 입지점 18에 할당됨
# 수요지 187는 시설물 입지점 18에 할당됨
# 수요지 188는 시설물 입지점 18에 할당됨
# 수요지 189는 시설물 입지점 18에 할당됨
# 수요지 190는 시설물 입지점 22에 할당됨
# 수요지 191는 시설물 입지점 20에 할당됨
# 수요지 192는 시설물 입지점 20에 할당됨
# 수요지 193는 시설물 입지점 18에 할당됨
# 수요지 194는 시설물 입지점 18에 할당됨
# 수요지 195는 시설물 입지점 18에 할당됨
# 수요지 196는 시설물 입지점 18에 할당됨
# 수요지 197는 시설물 입지점 18에 할당됨
# 수요지 198는 시설물 입지점 18에 할당됨
# 수요지 199는 시설물 입지점 18에 할당됨
# 수요지 200는 시설물 입지점 22에 할당됨
# 수요지 201는 시설물 입지점 20에 할당됨
# 수요지 202는 시설물 입지점 20에 할당됨
# 수요지 203는 시설물 입지점 20에 할당됨
# 수요지 204는 시설물 입지점 18에 할당됨
# 수요지 205는 시설물 입지점 18에 할당됨
# 수요지 206는 시설물 입지점 18에 할당됨
# 수요지 207는 시설물 입지점 18에 할당됨
# 수요지 208는 시설물 입지점 18에 할당됨
# 수요지 209는 시설물 입지점 20에 할당됨
# 수요지 210는 시설물 입지점 20에 할당됨
# 수요지 211는 시설물 입지점 20에 할당됨
# 수요지 212는 시설물 입지점 20에 할당됨
# 수요지 213는 시설물 입지점 20에 할당됨
# 수요지 214는 시설물 입지점 18에 할당됨
# 수요지 215는 시설물 입지점 18에 할당됨
# 수요지 216는 시설물 입지점 18에 할당됨
# 수요지 217는 시설물 입지점 18에 할당됨
# 수요지 218는 시설물 입지점 18에 할당됨
# 수요지 219는 시설물 입지점 6에 할당됨
# 수요지 220는 시설물 입지점 20에 할당됨
# 수요지 221는 시설물 입지점 20에 할당됨
# 수요지 222는 시설물 입지점 20에 할당됨
# 수요지 223는 시설물 입지점 20에 할당됨
# 수요지 224는 시설물 입지점 20에 할당됨
# 수요지 225는 시설물 입지점 20에 할당됨
# 수요지 226는 시설물 입지점 18에 할당됨
# 수요지 227는 시설물 입지점 18에 할당됨
# 수요지 228는 시설물 입지점 18에 할당됨
# 수요지 229는 시설물 입지점 18에 할당됨
# 수요지 230는 시설물 입지점 18에 할당됨
# 수요지 231는 시설물 입지점 20에 할당됨
# 수요지 232는 시설물 입지점 20에 할당됨
# 수요지 233는 시설물 입지점 20에 할당됨
# 수요지 234는 시설물 입지점 20에 할당됨
# 수요지 235는 시설물 입지점 20에 할당됨
# 수요지 236는 시설물 입지점 20에 할당됨
# 수요지 237는 시설물 입지점 18에 할당됨
# 수요지 238는 시설물 입지점 20에 할당됨
# 수요지 239는 시설물 입지점 20에 할당됨
# 수요지 240는 시설물 입지점 20에 할당됨
# 수요지 241는 시설물 입지점 20에 할당됨
# 수요지 242는 시설물 입지점 18에 할당됨
# 수요지 243는 시설물 입지점 18에 할당됨
# 수요지 244는 시설물 입지점 20에 할당됨
# 수요지 245는 시설물 입지점 20에 할당됨
# 수요지 246는 시설물 입지점 20에 할당됨
# 수요지 247는 시설물 입지점 20에 할당됨
# 수요지 248는 시설물 입지점 20에 할당됨
# 수요지 249는 시설물 입지점 20에 할당됨
# 수요지 250는 시설물 입지점 8에 할당됨
# 수요지 251는 시설물 입지점 8에 할당됨
# 수요지 252는 시설물 입지점 18에 할당됨
# 수요지 253는 시설물 입지점 20에 할당됨
# 수요지 254는 시설물 입지점 20에 할당됨
# 수요지 255는 시설물 입지점 20에 할당됨
# 수요지 256는 시설물 입지점 20에 할당됨
# 수요지 257는 시설물 입지점 20에 할당됨
# 수요지 258는 시설물 입지점 8에 할당됨
# 수요지 259는 시설물 입지점 20에 할당됨
# 수요지 260는 시설물 입지점 20에 할당됨
# 수요지 261는 시설물 입지점 20에 할당됨
# 수요지 262는 시설물 입지점 8에 할당됨
# 수요지 263는 시설물 입지점 20에 할당됨
# 수요지 264는 시설물 입지점 20에 할당됨
# 수요지 265는 시설물 입지점 20에 할당됨
# 수요지 266는 시설물 입지점 8에 할당됨
# 수요지 267는 시설물 입지점 8에 할당됨
# 수요지 268는 시설물 입지점 20에 할당됨
# 수요지 269는 시설물 입지점 20에 할당됨
# 수요지 270는 시설물 입지점 20에 할당됨
# 수요지 271는 시설물 입지점 8에 할당됨
# 수요지 272는 시설물 입지점 8에 할당됨
# 수요지 273는 시설물 입지점 8에 할당됨
# 수요지 274는 시설물 입지점 8에 할당됨
# 수요지 275는 시설물 입지점 8에 할당됨
# 수요지 276는 시설물 입지점 10에 할당됨
# 수요지 277는 시설물 입지점 30에 할당됨
# 수요지 278는 시설물 입지점 8에 할당됨
# 수요지 279는 시설물 입지점 8에 할당됨
# 수요지 280는 시설물 입지점 8에 할당됨
# 수요지 281는 시설물 입지점 8에 할당됨
# 수요지 282는 시설물 입지점 10에 할당됨
# 수요지 283는 시설물 입지점 30에 할당됨
# 수요지 284는 시설물 입지점 30에 할당됨
# 수요지 285는 시설물 입지점 8에 할당됨
# 수요지 286는 시설물 입지점 8에 할당됨
# 수요지 287는 시설물 입지점 8에 할당됨
# 수요지 288는 시설물 입지점 10에 할당됨
# 수요지 289는 시설물 입지점 30에 할당됨
# 수요지 290는 시설물 입지점 30에 할당됨
# 수요지 291는 시설물 입지점 30에 할당됨
# 수요지 292는 시설물 입지점 30에 할당됨
# 수요지 293는 시설물 입지점 30에 할당됨
# 수요지 294는 시설물 입지점 30에 할당됨
# 수요지 295는 시설물 입지점 10에 할당됨
# 수요지 296는 시설물 입지점 10에 할당됨
# 수요지 297는 시설물 입지점 30에 할당됨
# 수요지 298는 시설물 입지점 30에 할당됨
# 수요지 299는 시설물 입지점 10에 할당됨
# 수요지 300는 시설물 입지점 30에 할당됨
# 수요지 301는 시설물 입지점 30에 할당됨
# 수요지 302는 시설물 입지점 10에 할당됨
# 수요지 303는 시설물 입지점 30에 할당됨
# 수요지 304는 시설물 입지점 10에 할당됨
# 수요지 305는 시설물 입지점 10에 할당됨
# 수요지 306는 시설물 입지점 10에 할당됨
# 수요지 307는 시설물 입지점 10에 할당됨
# 수요지 308는 시설물 입지점 30에 할당됨
# 수요지 309는 시설물 입지점 10에 할당됨
# 수요지 310는 시설물 입지점 10에 할당됨
# 수요지 311는 시설물 입지점 10에 할당됨
# 시설물 입지점 2에 설치됨
# 시설물 입지점 3에 설치됨
# 시설물 입지점 6에 설치됨
# 시설물 입지점 8에 설치됨
# 시설물 입지점 10에 설치됨
# 시설물 입지점 18에 설치됨
# 시설물 입지점 20에 설치됨
# 시설물 입지점 22에 설치됨
# 시설물 입지점 23에 설치됨
# 시설물 입지점 30에 설치됨
# 시설물 입지점 34에 설치됨
# 시설물 입지점 35에 설치됨
# 시설물 입지점 37에 설치됨
# 시설물 입지점 39에 설치됨
# 시설물 입지점 40에 설치됨
# 시설물 입지점 44에 설치됨
# 시설물 입지점 45에 설치됨
# 시설물 입지점 47에 설치됨
# 시설물 입지점 48에 설치됨
#     시설물_입지점                                            연결된_수요지
# 0         2                                   [87, 90, 91, 93]
# 1         3                                   [13, 23, 26, 28]
# 2         6                                    [116, 138, 219]
# 3         8  [250, 251, 258, 262, 266, 267, 271, 272, 273, ...
# 4        10  [276, 282, 288, 295, 296, 299, 302, 304, 305, ...
# 5        18  [129, 139, 144, 145, 146, 147, 153, 154, 155, ...
# 6        20  [161, 171, 172, 178, 179, 180, 181, 191, 192, ...
# 7        22  [96, 98, 99, 103, 104, 105, 106, 107, 108, 109...
# 8        23                        [94, 95, 97, 100, 101, 102]
# 9        30  [277, 283, 284, 289, 290, 291, 292, 293, 294, ...
# 10       34                                   [80, 81, 88, 92]
# 11       35                                   [78, 79, 82, 84]
# 12       37  [46, 47, 49, 50, 51, 52, 53, 54, 55, 56, 57, 5...
# 13       39  [1, 38, 40, 41, 42, 43, 44, 45, 61, 77, 83, 85...
# 14       40                                       [33, 35, 39]
# 15       44                               [25, 27, 29, 30, 36]
# 16       45                      [2, 4, 5, 10, 14, 15, 16, 24]
# 17       47  [3, 6, 7, 8, 9, 11, 12, 17, 18, 19, 20, 21, 22...
# 18       48                                   [48, 68, 69, 75]
#     시설물_입지점  배정된_수요량
# 0         2      607
# 1         3      453
# 2         6      317
# 3         8      749
# 4        10      571
# 5        18      692
# 6        20      750
# 7        22      594
# 8        23      268
# 9        30      327
# 10       34      258
# 11       35      707
# 12       37      259
# 13       39      739
# 14       40      737
# 15       44      712
# 16       45      412
# 17       47      309
# 18       48      750
